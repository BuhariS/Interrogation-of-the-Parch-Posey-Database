# %% [markdown]
# <!DOCTYPE html>
# <head>
#     <meta charset="utf-8">
#     <link rel="stylesheet" href="styles.css">
#     <link href='https://fonts.googleapis.com/css?family=Merriweather' rel='stylesheet'>
#     <div style="background-color: #3D0069; color: white ; font-family: 'Merriweather'; font-weight: bold; text-align: center; padding: 40px 0; font-size: 16px;">
#     <h1>Interrogation of the Parch  & Posey Database</h1>
#         by
#
#     Buhari Shehu (The Datavestigator)
#     </div>
#
# </head>

# %% [markdown]
# <div style="background-color: #F5E8DA; font-family: 'Merriweather'; font-size: 16px;">
# <h2>Table of Contents</h2>
# <ol>
# <li><a href="#intro">Executive Summary</a></li>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#wrangling">Methodology</a></li>
# <li><a href="#eda">Analysis</a></li>
# <li><a href="#conclusions">Conclusions</a></li>
# <li><a href="#model">Recommendations</a></li>
# <li><a href="#references">References</a></li>
# </ol>
# </div>

# %% [markdown]
# <link href='https://fonts.googleapis.com/css?family=Merriweather' rel='stylesheet'>
# <h2 style="background-color: #F5E8DA; color: #50006C; font-family: 'Merriweather'; font-weight: bold; font-size: 20px; text-align: center; padding: 10px 0;">
#   Introduction
# </h2>

# %% [markdown]
# <img src="erd.png" width=800 height=400 />

# %%
# %%sql
# SELECT t1.id, t1.name, t1.channel, MAX(count) max_chan
# FROM (SELECT a.id, a.name, w.channel, COUNT(*) count
# FROM accounts a
# JOIN web_events w
# ON a.id = w.account_id
# GROUP BY 1, 2, 3) t1
# GROUP BY 1, 2

# %%
# %%sql
# SELECT id,
#         account_id,
#         standard_qty,
#         STRFTIME('%Y %m', occurred_at) month,
#         DENSE_RANK() OVER (PARTITION BY account_id ORDER BY STRFTIME('%Y %m', occurred_at)) AS dense_rank,
#         SUM(standard_qty) OVER (PARTITION BY account_id ORDER BY STRFTIME('%Y %m', occurred_at)) AS running_sum_std_qty,
#         COUNT(standard_qty) OVER (PARTITION BY account_id ORDER BY STRFTIME('%Y %m', occurred_at)) AS count__std_qty,
#         AVG(standard_qty) OVER (PARTITION BY account_id ORDER BY STRFTIME('%Y %m', occurred_at)) AS avg__std_qty,
#         MIN(standard_qty) OVER (PARTITION BY account_id ORDER BY STRFTIME('%Y %m', occurred_at)) AS min__std_qty,
#         MAX(standard_qty) OVER (PARTITION BY account_id ORDER BY STRFTIME('%Y %m', occurred_at)) AS max__std_qty
# FROM orders

# %%
# %%sql
# WITH cte AS (SELECT account_id,
#         SUM(standard_qty) AS sum_std_qty
#         FROM orders
#         GROUP BY 1)
# SELECT  account_id,
#         sum_std_qty,
#         LAG(sum_std_qty) OVER (ORDER BY sum_std_qty) AS lag,
#         LEAD(sum_std_qty) OVER (ORDER BY sum_std_qty) AS lead,
#         sum_std_qty - LAG(sum_std_qty) OVER (ORDER BY sum_std_qty) AS lag_diffrence,
#         LEAD(sum_std_qty) OVER (ORDER BY sum_std_qty) - sum_std_qty AS lead_diffrence
# FROM cte

# %%
# %%sql
# SELECT id, account_id, standard_qty, SUM(standard_qty) OVER (ORDER BY id) AS total
# FROM orders;

# %%
# %%sql
# SELECT id,
#         account_id,
#         occurred_at,
#         standard_qty,
#         NTILE(4) OVER (ORDER BY standard_qty) AS quartile,
#         NTILE(5) OVER (ORDER BY standard_qty) AS quintile,
#         NTILE(100) OVER (ORDER BY standard_qty) AS percentile
# FROM orders
# ORDER BY standard_qty DESC

# %%
# %%sql
# SELECT t3.id, t3.name, t3.channel, t3.count
# FROM (SELECT a.id, a.name, w.channel, COUNT(*) count
# FROM accounts a
# JOIN web_events w
# ON a.id = w.account_id
# GROUP BY 1, 2, 3) t3
#
#
# JOIN (SELECT t1.id, t1.name, MAX(count) max_chan
# FROM (SELECT a.id, a.name, w.channel, COUNT(*) count
# FROM accounts a
# JOIN web_events w
# ON a.id = w.account_id
# GROUP BY 1, 2, 3) t1
# GROUP BY 1, 2
# ORDER BY 1) t2
# ON t2.id = t3.id AND t2.max_chan = t3.count
# ORDER BY 1, 4

# %%
# %%sql
# SELECT standard_qty,
#        SUM(total) OVER(ORDER BY occurred_at) AS running_total
# FROM orders

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %%sql
# SELECT strftime('%Y %m', occurred_at) months, ROUND(AVG(total_amt_usd), 2) average_sales
# FROM orders
# WHERE occurred_at LIKE '2015%'
# GROUP BY 1
# Out:
#  * sqlite:///pandp.db
# Done.
# [('2015 01', 2922.73),
#  ('2015 02', 3239.69),
#  ('2015 03', 4026.38),
#  ('2015 04', 3672.79),
#  ('2015 05', 2916.65),
#  ('2015 06', 3314.22),
#  ('2015 07', 3163.67),
#  ('2015 08', 3198.31),
#  ('2015 09', 3648.92),
#  ('2015 10', 3166.8),
#  ('2015 11', 3789.41),
#  ('2015 12', 3013.9)]

# %%
# %%sql
# SELECT w.channel, ROUND(SUM(o.total_amt_usd), 2) total_sales
# FROM orders o
# JOIN accounts a
# ON o.account_id = a.id
# JOIN web_events w
# ON w.account_id = a.id
# WHERE o.occurred_at BETWEEN '2015-01-01' AND '2016-01-01'
# GROUP BY 1
# ORDER BY 2 DESC;
# Out:
#  * sqlite:///pandp.db
# Done.
# [('direct', 201196130.62),
#  ('facebook', 31954065.03),
#  ('organic', 31918987.73),
#  ('adwords', 30321237.21),
#  ('twitter', 16374278.84),
#  ('banner', 14248005.61)]

# %% [markdown]
# ## 2. Connecting to a serverless SQL database
#
# We can connect to a SQLite database as follows:
#
# 1. We need to install some dependencies. This includes the following Python modules:
#
#  - Running ***locally***: Once-off installations
#       - `pip install sqlalchemy`
#       - `pip install ipython-sql`
#       - `pip install pymysql`
#
#  - Running on ***Google Colab***:
#       - no dependencies required

# %%
# %load_ext sql

# %%
# Load SQLite database
# %sql sqlite:///pandp.db

# %% [markdown]
# <div style="border: 5px solid #6f00ff;
#     border-radius: 20px; text-align: center; font-size: 20px; font-family: 'Merriweather'; padding: 16px 0; background-color: #D9EEE1">
#   <b>Which tables are in the database?</b>
# </div>

# %%
# %%sql
# SELECT name
# FROM sqlite_master
# WHERE type IN ('table','view') AND name NOT LIKE 'sqlite_%'
# ORDER BY 1;
# Out:
#  * sqlite:///pandp.db
# Done.
# [('accounts',), ('orders',), ('region',), ('sales_reps',), ('web_events',)]

# %%
# %%sql
# SELECT *
# FROM orders
# LIMIT 5;
# Out:
#  * sqlite:///pandp.db
# Done.
# [(1, 1001, '2015-10-06 17:31:14', 123, 22, 24, 169, 613.77, 164.78, 194.88, 973.43),
#  (2, 1001, '2015-11-05 03:34:33', 190, 41, 57, 288, 948.1, 307.09, 462.84, 1718.03),
#  (3, 1001, '2015-12-04 04:21:55', 85, 47, 0, 132, 424.15, 352.03, 0, 776.18),
#  (4, 1001, '2016-01-02 01:18:24', 144, 32, 0, 176, 718.56, 239.68, 0, 958.24),
#  (5, 1001, '2016-02-01 19:27:27', 108, 29, 28, 165, 538.92, 217.21, 227.36, 983.49)]

# %% [markdown]
# <div style="border: 5px solid #000;
#     border-radius: 20px; text-align: center; font-size: 20px; font-family: 'Merriweather'; padding: 16px 0; background-color: #FFF4A3">
#   <b>What are the five latest orders?<b>
# </div>

# %%
# %%sql
# SELECT *
# FROM orders
# ORDER BY occurred_at DESC
# LIMIT 5;
# Out:
#  * sqlite:///pandp.db
# Done.
# [(6451, 3841, '2017-01-02 00:02:40', 42, 506, 302, 850, 209.58, 3789.94, 2452.24, 6451.76),
#  (3546, 3841, '2017-01-01 23:50:16', 291, 36, 26, 353, 1452.09, 269.64, 211.12, 1932.85),
#  (6454, 3861, '2017-01-01 22:29:50', 38, 167, 51, 256, 189.62, 1250.83, 414.12, 1854.57),
#  (3554, 3861, '2017-01-01 22:17:26', 497, 0, 23, 520, 2480.03, 0, 186.76, 2666.79),
#  (6556, 4051, '2017-01-01 21:04:25', 0, 65, 50, 115, 0, 486.85, 406, 892.85)]

# %% [markdown]
# <div style="border: 5px solid #6f00ff;
#     border-radius: 20px; text-align: center; font-size: 20px; font-family: 'Merriweather'; padding: 16px 0; background-color: #F5E8DA">
#   <b>In which accounts did the top five purchases of all time occur?<b>
# </div>

# %%
# %%sql
# SELECT account_id, total_amt_usd
# FROM orders
# ORDER BY total_amt_usd DESC
# LIMIT 5;
# Out:
#  * sqlite:///pandp.db
# Done.
# [(4251, 232207.07),
#  (4161, 112875.18),
#  (4211, 107533.55),
#  (2861, 95005.82),
#  (4101, 93547.84)]

# %% [markdown]
# <div style="border: 5px solid #6f00ff;
#     border-radius: 20px; text-align: center; font-size: 20px; font-family: 'Merriweather'; padding: 16px 0; background-color: #F5E8DA">
#   <b>In which accounts did the lowest five purchases of all time occur?<b>
# </div>

# %%
# %%sql
# SELECT account_id, total_amt_usd
# FROM orders
# ORDER BY total_amt_usd
# LIMIT 5;
# Out:
#  * sqlite:///pandp.db
# Done.
# [(1131, 0), (1951, 0), (2881, 0), (1221, 0), (1231, 0)]

# %% [markdown]
# <div style="border: 5px solid #6f00ff;
#     border-radius: 20px; text-align: center; font-size: 20px; font-family: 'Merriweather'; padding: 16px 0; background-color: #F5E8DA">
#   <b>Which records have total purchase greater than $100,000 ?<b>
# </div>

# %%
# %%sql
# SELECT *
# FROM orders
# WHERE total_amt_usd > 100000;
# Out:
#  * sqlite:///pandp.db
# Done.
# [(3892, 4161, '2016-06-24 13:32:55', 22591, 13, 6, 22610, 112729.09, 97.37, 48.72, 112875.18),
#  (3963, 4211, '2015-03-30 00:05:30', 114, 14281, 0, 14395, 568.86, 106964.69, 0, 107533.55),
#  (4016, 4251, '2016-12-26 08:53:24', 521, 16, 28262, 28799, 2599.79, 119.84, 229487.44, 232207.07)]

# %%
#Which channel which sales rep in what region names of companies that these sales were made?
# %%sql
SELECT w.channel
FROM orders
JOIN web_events w
WHERE total_amt_usd > 100000;

# %% [markdown]
# <div style="border: 5px solid #6f00ff;
#     border-radius: 20px; text-align: center; font-size: 20px; font-family: 'Merriweather'; padding: 16px 0; background-color: #F5E8DA">
#   <b>What are the account names and the sales representative for the top three accounts above?</b>
# </div>

# %%
# %%sql
# SELECT a.name account_name, s.name sales_rep,  o.total_amt_usd
# FROM orders o
# JOIN accounts a
# ON o.account_id = a.id
# JOIN sales_reps s
# ON a.sales_rep_id = s.id
# WHERE total_amt_usd > 100000
# ORDER BY 3 DESC;
# Out:
#  * sqlite:///pandp.db
# Done.
# [('Pacific Life', 'Dawna Agnew', 232207.07),
#  ('Core-Mark Holding', 'Maryanna Fiorentino', 112875.18),
#  ('EOG Resources', 'Arica Stoltzfus', 107533.55)]

# %% [markdown]
# <div style="border: 5px solid #6f00ff;
#     border-radius: 20px; text-align: center; font-size: 20px; font-family: 'Merriweather'; padding: 16px 0; background-color: #F5E8DA">
#   <b>What are the names, websites and primary points of contact of the top three accounts above?<b>
# </div>

# %%
# %%sql
# SELECT name, website, primary_poc
# FROM accounts
# WHERE id in (4161, 4211, 4251);
# Out:
#  * sqlite:///pandp.db
# Done.
# [('Core-Mark Holding', 'www.core-mark.com', 'Marita Demasi'),
#  ('EOG Resources', 'www.eogresources.com', 'Alida Desrosier'),
#  ('Pacific Life', 'www.pacificlife.com', 'Kyoko Randall')]

# %% [markdown]
# <div style="border: 5px solid #6f00ff;
#     border-radius: 20px; text-align: center; font-size: 20px; font-family: 'Merriweather'; padding: 16px 0; background-color: #F5E8DA">
#   <b>What is the unit price of a standard paper?</b>
# </div>

# %%
# %%sql
# SELECT standard_amt_usd/standard_qty standard_paper_unit_price_usd
# FROM orders
# LIMIT 1;
# Out:
#  * sqlite:///pandp.db
# Done.
# [(4.99,)]

# %% [markdown]
# <div style="border: 5px solid #6f00ff;
#     border-radius: 20px; text-align: center; font-size: 20px; font-family: 'Merriweather'; padding: 16px 0; background-color: #F5E8DA">
#   <b>Which orders contain only standard paper with a quantity greater than 1000?<b>
# </div>

# %%
# %%sql
# SELECT *
# FROM orders
# WHERE standard_qty > 1000 AND poster_qty = 0 AND gloss_qty = 0;
# Out:
#  * sqlite:///pandp.db
# Done.
# [(2613, 2951, '2016-08-15 00:06:12', 1171, 0, 0, 1171, 5843.29, 0, 0, 5843.29),
#  (3260, 3491, '2014-08-29 22:43:00', 1552, 0, 0, 1552, 7744.48, 0, 0, 7744.48)]

# %% [markdown]
# <div style="border: 5px solid #6f00ff;
#     border-radius: 20px; text-align: center; font-size: 20px; font-family: 'Merriweather'; padding: 16px 0; background-color: #F5E8DA">
#   <b>Which orders were placed between 2014-12-29 and 2014-12-30?</b>
# </div>

# %%
# %%sql
# SELECT *
# FROM orders
# WHERE occurred_at BETWEEN '2014-12-29' AND '2014-12-31';
# Out:
#  * sqlite:///pandp.db
# Done.
# [(256, 1251, '2014-12-30 02:30:01', 336, 52, 12, 400, 1676.64, 389.48, 97.44, 2163.56),
#  (604, 1451, '2014-12-29 07:50:25', 412, 0, 0, 412, 2055.88, 0, 0, 2055.88),
#  (3084, 3411, '2014-12-29 06:34:35', 286, 12, 22, 320, 1427.14, 89.88, 178.64, 1695.66),
#  (3960, 4211, '2014-12-29 22:37:31', 96, 19, 16, 131, 479.04, 142.31, 129.92, 751.27),
#  (4163, 4341, '2014-12-29 04:40:43', 584, 36, 12, 632, 2914.16, 269.64, 97.44, 3281.24),
#  (4465, 1251, '2014-12-30 02:10:42', 510, 574, 202, 1286, 2544.9, 4299.26, 1640.24, 8484.4),
#  (4697, 1451, '2014-12-29 07:40:17', 54, 542, 271, 867, 269.46, 4059.58, 2200.52, 6529.56),
#  (6168, 3411, '2014-12-29 06:27:25', 43, 615, 301, 959, 214.57, 4606.35, 2444.12, 7265.04),
#  (6688, 4211, '2014-12-29 22:41:19', 513, 568, 190, 1271, 2559.87, 4254.32, 1542.8, 8356.99)]

# %%
# %%sql
# SELECT orders.*,
# accounts.*
# FROM orders
# JOIN accounts
# ON orders.account_id = accounts.id
# LIMIT 5;
# Out:
#  * sqlite:///pandp.db
# Done.
# [(1, 1001, '2015-10-06 17:31:14', 123, 22, 24, 169, 613.77, 164.78, 194.88, 973.43, 1001, 'Walmart', 'www.walmart.com', 40.23849561, -75.10329704, 'Tamara Tuma', 321500),
#  (2, 1001, '2015-11-05 03:34:33', 190, 41, 57, 288, 948.1, 307.09, 462.84, 1718.03, 1001, 'Walmart', 'www.walmart.com', 40.23849561, -75.10329704, 'Tamara Tuma', 321500),
#  (3, 1001, '2015-12-04 04:21:55', 85, 47, 0, 132, 424.15, 352.03, 0, 776.18, 1001, 'Walmart', 'www.walmart.com', 40.23849561, -75.10329704, 'Tamara Tuma', 321500),
#  (4, 1001, '2016-01-02 01:18:24', 144, 32, 0, 176, 718.56, 239.68, 0, 958.24, 1001, 'Walmart', 'www.walmart.com', 40.23849561, -75.10329704, 'Tamara Tuma', 321500),
#  (5, 1001, '2016-02-01 19:27:27', 108, 29, 28, 165, 538.92, 217.21, 227.36, 983.49, 1001, 'Walmart', 'www.walmart.com', 40.23849561, -75.10329704, 'Tamara Tuma', 321500)]

# %% [markdown]
# <div style="border: 5px solid #6f00ff;
#     border-radius: 20px; text-align: center; font-size: 20px; font-family: 'Merriweather'; padding: 16px 0; background-color: #F5E8DA">
#   <b>How much sales were generated by each channel in 2015?</b>
# </div>

# %%
# %%sql
# SELECT w.channel, ROUND(SUM(o.total_amt_usd/1e6), 2) total_sales_million_usd
# FROM orders o
# JOIN accounts a
# ON o.account_id = a.id
# JOIN web_events w
# ON w.account_id = a.id
# WHERE o.occurred_at BETWEEN '2015-01-01' AND '2016-01-01'
# GROUP BY 1
# ORDER BY 2 DESC;
# Out:
#  * sqlite:///pandp.db
# Done.
# [('direct', 201.2),
#  ('facebook', 31.95),
#  ('organic', 31.92),
#  ('adwords', 30.32),
#  ('twitter', 16.37),
#  ('banner', 14.25)]

# %%
# create revenue by channel
channel = %sql SELECT w.channel, ROUND(SUM(o.total_amt_usd/1e6), 2) total_sales_million_usd FROM orders o JOIN accounts a ON o.account_id = a.id JOIN web_events w ON w.account_id = a.id WHERE o.occurred_at BETWEEN '2015-01-01' AND '2016-01-01' GROUP BY 1 ORDER BY 2 DESC;
channel_df = channel.DataFrame()
# Out:
#  * sqlite:///pandp.db
# Done.

# %%
# Create a bar plot with the 'channel' column on the x-axis and the 'total_sales_million_usd' column on the y-axis
# Define colour palette
colour = '#3D0069'
colours = [colour for i in range(len(channel_df)-1)]
palette = ['red']
palette.extend(colours)

ax = sns.barplot(x='channel', y='total_sales_million_usd', data=channel_df, palette=palette)

# Set the x-axis label to 'Channels'
ax.set_xlabel('Channels')

# Set the y-axis label to 'Total sales in million USD'
ax.set_ylabel('Total sales in million USD')

# Set the title to 'Revenue by channel in 2015'
ax.set_title('Sales by channel in 2015');

# %%
# %%sql
# SELECT MAX(occurred_at)
# FROM orders
# Out:
#  * sqlite:///pandp.db
# Done.
# [('2017-01-02 00:02:40',)]

# %%
# %%sql
# SELECT MIN(occurred_at)
# FROM orders
# Out:
#  * sqlite:///pandp.db
# Done.
# [('2013-12-04 04:22:44',)]

# %% [markdown]
# <div style="border: 5px solid #6f00ff;
#     border-radius: 20px; text-align: center; font-size: 20px; font-family: 'Merriweather'; padding: 16px 0; background-color: #F5E8DA">
#   <b>Comparing 2016 to 2015, how did sales fare?</b>
# </div>

# %%
# %%sql
# SELECT strftime('%Y %m', occurred_at) years, strftime('%m', occurred_at) months, ROUND(AVG(total_amt_usd), 2) average_sales
# FROM orders
# WHERE occurred_at LIKE '2015%' OR occurred_at LIKE '2016%'
# GROUP BY 1
# Out:
#  * sqlite:///pandp.db
# Done.
# [('2015 01', '01', 2922.73),
#  ('2015 02', '02', 3239.69),
#  ('2015 03', '03', 4026.38),
#  ('2015 04', '04', 3672.79),
#  ('2015 05', '05', 2916.65),
#  ('2015 06', '06', 3314.22),
#  ('2015 07', '07', 3163.67),
#  ('2015 08', '08', 3198.31),
#  ('2015 09', '09', 3648.92),
#  ('2015 10', '10', 3166.8),
#  ('2015 11', '11', 3789.41),
#  ('2015 12', '12', 3013.9),
#  ('2016 01', '01', 2978.89),
#  ('2016 02', '02', 3069.3),
#  ('2016 03', '03', 3301.95),
#  ('2016 04', '04', 3124.04),
#  ('2016 05', '05', 2996.53),
#  ('2016 06', '06', 3906.97),
#  ('2016 07', '07', 3885.15),
#  ('2016 08', '08', 3189.64),
#  ('2016 09', '09', 3446.86),
#  ('2016 10', '10', 3542.37),
#  ('2016 11', '11', 3284.81),
#  ('2016 12', '12', 3823.5)]

# %%
average_sales = %sql SELECT strftime('%Y %m', occurred_at) years, strftime('%m', occurred_at) months, ROUND(AVG(total_amt_usd), 2) average_sales FROM orders WHERE occurred_at LIKE '2015%' OR occurred_at LIKE '2016%' GROUP BY 1
average_sales_df = average_sales.DataFrame()
# Out:
#  * sqlite:///pandp.db
# Done.

# %%
3301.95 - 4026.38
# Out:
# -724.4300000000003

# %%
average_sales_df
# Out:
#       years months  average_sales
# 0   2015 01     01        2922.73
# 1   2015 02     02        3239.69
# 2   2015 03     03        4026.38
# 3   2015 04     04        3672.79
# 4   2015 05     05        2916.65
# 5   2015 06     06        3314.22
# 6   2015 07     07        3163.67
# 7   2015 08     08        3198.31
# 8   2015 09     09        3648.92
# 9   2015 10     10        3166.80
# 10  2015 11     11        3789.41
# 11  2015 12     12        3013.90
# 12  2016 01     01        2978.89
# 13  2016 02     02        3069.30
# 14  2016 03     03        3301.95
# 15  2016 04     04        3124.04
# 16  2016 05     05        2996.53
# 17  2016 06     06        3906.97
# 18  2016 07     07        3885.15
# 19  2016 08     08        3189.64
# 20  2016 09     09        3446.86
# 21  2016 10     10        3542.37
# 22  2016 11     11        3284.81
# 23  2016 12     12        3823.50

# %%
average_sales_df['yoy_change'] = average_sales_df['average_sales'] - average_sales_df['average_sales'].shift(12)
# Set the figure size to 10 inches wide and 6 inches tall

plt.figure(figsize=(15, 6))
# Create a line plot with the year on the x-axis and the YoY change on the y-axis
sns.lineplot(x='months', y='yoy_change', data=average_sales_df)
# Out:
# <AxesSubplot:xlabel='months', ylabel='yoy_change'>

# %% [markdown]
# - high variability
# - overall 2015 was better
# - seems no seasonality in the dataset
# - high volatility = high variability?

# %% [markdown]
# <div style="border: 5px solid #6f00ff;
#     border-radius: 20px; text-align: center; font-size: 20px; font-family: 'Merriweather'; padding: 16px 0; background-color: #F5E8DA">
#   <b>What are the 10 latest orders?<b>
# </div>

# %% [markdown]
# Which channel send the most traffic per day on average to parch and posey
# Solution: we need to aggregate events by channel by day then we average them

# %%
# %%sql
# SELECT channel,
#        AVG(event_count) AS avg_event_count
# FROM
# (SELECT strftime('%Y %m %d', occurred_at) day,
#         channel,
#         COUNT(*) event_count
# FROM web_events
# GROUP BY 1, 2) sub
# GROUP BY 1
# ORDER BY 2 DESC
# Out:
#  * sqlite:///pandp.db
# Done.
# [('direct', 4.896487985212569),
#  ('organic', 1.6672504378283712),
#  ('facebook', 1.5983471074380164),
#  ('adwords', 1.5701906412478337),
#  ('twitter', 1.3166666666666667),
#  ('banner', 1.2899728997289972)]

# %% [markdown]
#  return only orders that occurred in the same month as PandP first order ever

# %%
# %%sql
# SELECT *
# FROM orders
# WHERE STRFTIME('%Y %m', occurred_at) LIKE (SELECT STRFTIME('%Y %m', MIN(occurred_at)) earliest_month FROM orders)
# Out:
#  * sqlite:///pandp.db
# Done.
# [(147, 1181, '2013-12-17 23:02:57', 339, 0, 0, 339, 1691.61, 0, 0, 1691.61),
#  (243, 1251, '2013-12-11 20:36:06', 86, 39, 34, 159, 429.14, 292.11, 276.08, 997.33),
#  (287, 1281, '2013-12-05 20:33:56', 492, 73, 0, 565, 2455.08, 546.77, 0, 3001.85),
#  (346, 1301, '2013-12-08 07:05:07', 85, 89, 32, 206, 424.15, 666.61, 259.84, 1350.6),
#  (446, 1401, '2013-12-12 16:33:14', 299, 39, 28, 366, 1492.01, 292.11, 227.36, 2011.48),
#  (484, 1411, '2013-12-30 21:42:43', 498, 41, 0, 539, 2485.02, 307.09, 0, 2792.11),
#  (561, 1441, '2013-12-28 12:54:50', 317, 30, 5, 352, 1581.83, 224.7, 40.6, 1847.13),
#  (702, 1521, '2013-12-31 00:36:59', 266, 0, 26, 292, 1327.34, 0, 211.12, 1538.46),
#  (739, 1531, '2013-12-10 14:43:18', 501, 0, 0, 501, 2499.99, 0, 0, 2499.99),
#  (795, 1561, '2013-12-17 21:54:36', 380, 109, 0, 489, 1896.2, 816.41, 0, 2712.61),
#  (881, 1601, '2013-12-14 09:19:37', 516, 0, 122, 638, 2574.84, 0, 990.64, 3565.48),
#  (1008, 1701, '2013-12-12 04:47:28', 148, 7, 134, 289, 738.52, 52.43, 1088.08, 1879.03),
#  (1084, 1751, '2013-12-12 17:49:47', 150, 0, 3, 153, 748.5, 0, 24.36, 772.86),
#  (1129, 1791, '2013-12-09 15:39:02', 481, 0, 0, 481, 2400.19, 0, 0, 2400.19),
#  (1230, 1871, '2013-12-22 19:43:00', 289, 24, 30, 343, 1442.11, 179.76, 243.6, 1865.47),
#  (1268, 1881, '2013-12-08 18:32:52', 501, 67, 1647, 2215, 2499.99, 501.83, 13373.64, 16375.46),
#  (1348, 1951, '2013-12-18 10:36:28', 151, 19, 41, 211, 753.49, 142.31, 332.92, 1228.72),
#  (1421, 2051, '2013-12-29 23:42:44', 498, 30, 9, 537, 2485.02, 224.7, 73.08, 2782.8),
#  (1468, 2081, '2013-12-11 16:34:12', 311, 0, 0, 311, 1551.89, 0, 0, 1551.89),
#  (1507, 2111, '2013-12-27 05:09:46', 110, 27, 0, 137, 548.9, 202.23, 0, 751.13),
#  (1563, 2181, '2013-12-24 20:36:08', 278, 14, 46, 338, 1387.22, 104.86, 373.52, 1865.6),
#  (1624, 2231, '2013-12-30 03:52:30', 304, 7, 48, 359, 1516.96, 52.43, 389.76, 1959.15),
#  (1732, 2331, '2013-12-11 07:45:07', 142, 83, 6, 231, 708.58, 621.67, 48.72, 1378.97),
#  (1767, 2351, '2013-12-16 06:16:57', 491, 1, 8, 500, 2450.09, 7.49, 64.96, 2522.54),
#  (1825, 2371, '2013-12-27 22:08:03', 92, 0, 48, 140, 459.08, 0, 389.76, 848.84),
#  (1845, 2381, '2013-12-14 10:37:07', 1051, 37, 101, 1189, 5244.49, 277.13, 820.12, 6341.74),
#  (1865, 2411, '2013-12-16 02:27:22', 506, 4, 40, 550, 2524.94, 29.96, 324.8, 2879.7),
#  (1913, 2461, '2013-12-29 09:50:38', 0, 6450, 45, 6495, 0, 48310.5, 365.4, 48675.9),
#  (1946, 2481, '2013-12-06 02:13:20', 502, 4, 33, 539, 2504.98, 29.96, 267.96, 2802.9),
#  (2012, 2531, '2013-12-25 04:33:01', 142, 4, 0, 146, 708.58, 29.96, 0, 738.54),
#  (2025, 2541, '2013-12-21 17:14:11', 290, 0, 18, 308, 1447.1, 0, 146.16, 1593.26),
#  (2071, 2571, '2013-12-19 17:37:45', 286, 20, 26, 332, 1427.14, 149.8, 211.12, 1788.06),
#  (2086, 2591, '2013-12-11 03:17:57', 310, 44, 13, 367, 1546.9, 329.56, 105.56, 1982.02),
#  (2152, 2631, '2013-12-23 07:09:20', 481, 18, 0, 499, 2400.19, 134.82, 0, 2535.01),
#  (2305, 2731, '2013-12-08 00:54:42', 490, 12, 6, 508, 2445.1, 89.88, 48.72, 2583.7),
#  (2356, 2771, '2013-12-19 16:52:20', 107, 35, 25, 167, 533.93, 262.15, 203, 999.08),
#  (2415, 2861, '2013-12-04 04:45:54', 490, 15, 11, 516, 2445.1, 112.35, 89.32, 2646.77),
#  (2454, 2871, '2013-12-14 21:40:29', 533, 11, 0, 544, 2659.67, 82.39, 0, 2742.06),
#  (2492, 2881, '2013-12-22 07:29:58', 497, 23, 10, 530, 2480.03, 172.27, 81.2, 2733.5),
#  (2566, 2931, '2013-12-18 23:35:31', 300, 31, 39, 370, 1497, 232.19, 316.68, 2045.87),
#  (2623, 2971, '2013-12-30 04:30:03', 287, 1, 17, 305, 1432.13, 7.49, 138.04, 1577.66),
#  (2692, 3051, '2013-12-17 12:04:46', 493, 17, 12, 522, 2460.07, 127.33, 97.44, 2684.84),
#  (2764, 3101, '2013-12-31 12:58:47', 119, 36, 0, 155, 593.81, 269.64, 0, 863.45),
#  (2811, 3141, '2013-12-08 20:37:53', 501, 0, 25, 526, 2499.99, 0, 203, 2702.99),
#  (2932, 3251, '2013-12-06 13:17:25', 281, 39, 47, 367, 1402.19, 292.11, 381.64, 2075.94),
#  (3057, 3371, '2013-12-31 02:04:00', 79, 75, 14, 168, 394.21, 561.75, 113.68, 1069.64),
#  (3071, 3411, '2013-12-13 17:58:50', 315, 71, 0, 386, 1571.85, 531.79, 0, 2103.64),
#  (3122, 3431, '2013-12-06 12:57:41', 308, 25, 33, 366, 1536.92, 187.25, 267.96, 1992.13),
#  (3170, 3461, '2013-12-26 11:33:53', 508, 24, 13, 545, 2534.92, 179.76, 105.56, 2820.24),
#  (3207, 3471, '2013-12-29 21:43:14', 353, 5, 13, 371, 1761.47, 37.45, 105.56, 1904.48),
#  (3251, 3491, '2013-12-06 23:47:45', 461, 9, 7, 477, 2300.39, 67.41, 56.84, 2424.64),
#  (3558, 3881, '2013-12-15 23:48:05', 489, 11, 0, 500, 2440.11, 82.39, 0, 2522.5),
#  (3784, 4111, '2013-12-25 21:16:18', 304, 26, 24, 354, 1516.96, 194.74, 194.88, 1906.58),
#  (3824, 4151, '2013-12-22 11:29:05', 305, 33, 25, 363, 1521.95, 247.17, 203, 1972.12),
#  (3861, 4161, '2013-12-21 16:09:46', 504, 14, 0, 518, 2514.96, 104.86, 0, 2619.82),
#  (3947, 4211, '2013-12-12 09:48:16', 95, 0, 32, 127, 474.05, 0, 259.84, 733.89),
#  (4062, 4291, '2013-12-28 18:36:42', 297, 53, 5, 355, 1482.03, 396.97, 40.6, 1919.6),
#  (4108, 4311, '2013-12-04 04:53:25', 528, 10, 0, 538, 2634.72, 74.9, 0, 2709.62),
#  (4150, 4341, '2013-12-10 16:25:51', 639, 0, 0, 639, 3188.61, 0, 0, 3188.61),
#  (4226, 4451, '2013-12-09 22:19:26', 491, 2, 4, 497, 2450.09, 14.98, 32.48, 2497.55),
#  (4457, 1251, '2013-12-11 20:42:09', 484, 582, 236, 1302, 2415.16, 4359.18, 1916.32, 8690.66),
#  (4489, 1281, '2013-12-05 20:29:16', 0, 37, 0, 37, 0, 277.13, 0, 277.13),
#  (4523, 1301, '2013-12-08 07:11:38', 477, 600, 167, 1244, 2380.23, 4494, 1356.04, 8230.27),
#  (4587, 1401, '2013-12-12 16:26:53', 38, 381, 305, 724, 189.62, 2853.69, 2476.6, 5519.91),
#  (4615, 1411, '2013-12-30 21:46:00', 150, 645, 0, 795, 748.5, 4831.05, 0, 5579.55),
#  (4756, 1521, '2013-12-31 00:18:22', 10, 60, 29, 99, 49.9, 449.4, 235.48, 734.78),
#  (4776, 1531, '2013-12-10 14:36:56', 0, 8, 78, 86, 0, 59.92, 633.36, 693.28),
#  (4813, 1561, '2013-12-17 21:43:40', 63, 534, 282, 879, 314.37, 3999.66, 2289.84, 6603.87),
#  (4992, 1791, '2013-12-09 15:42:23', 0, 43, 0, 43, 0, 322.07, 0, 322.07),
#  (5059, 1871, '2013-12-22 19:48:13', 0, 796, 288, 1084, 0, 5962.04, 2338.56, 8300.6),
#  (5087, 1881, '2013-12-08 18:24:52', 1780, 47, 0, 1827, 8882.2, 352.03, 0, 9234.23),
#  (5179, 2051, '2013-12-29 23:54:00', 0, 85, 0, 85, 0, 636.65, 0, 636.65),
#  (5279, 2181, '2013-12-24 20:42:09', 30, 528, 302, 860, 149.7, 3954.72, 2452.24, 6556.66),
#  (5322, 2231, '2013-12-30 04:00:40', 51, 501, 304, 856, 254.49, 3752.49, 2468.48, 6475.46),
#  (5411, 2351, '2013-12-16 06:34:38', 0, 52, 15, 67, 0, 389.48, 121.8, 511.28),
#  (5450, 2381, '2013-12-14 10:24:39', 0, 80, 0, 80, 0, 599.2, 0, 599.2),
#  (5481, 2461, '2013-12-29 09:35:57', 57, 97, 81, 235, 284.43, 726.53, 657.72, 1668.68),
#  (5537, 2541, '2013-12-21 17:13:55', 69, 480, 283, 832, 344.31, 3595.2, 2297.96, 6237.47),
#  (5569, 2571, '2013-12-19 17:36:09', 34, 520, 165, 719, 169.66, 3894.8, 1339.8, 5404.26),
#  (5582, 2591, '2013-12-11 03:42:54', 217, 499, 309, 1025, 1082.83, 3737.51, 2509.08, 7329.42),
#  (5622, 2631, '2013-12-23 07:18:28', 6, 506, 0, 512, 29.94, 3789.94, 0, 3819.88),
#  (5754, 2771, '2013-12-19 16:57:14', 501, 583, 193, 1277, 2499.99, 4366.67, 1567.16, 8433.82),
#  (5786, 2861, '2013-12-04 04:22:44', 0, 48, 33, 81, 0, 359.52, 267.96, 627.48),
#  (5807, 2871, '2013-12-14 21:42:11', 20, 50, 19, 89, 99.8, 374.5, 154.28, 628.58),
#  (5830, 2881, '2013-12-22 07:35:42', 0, 66, 27, 93, 0, 494.34, 219.24, 713.58),
#  (5876, 2931, '2013-12-18 23:41:14', 68, 464, 1040, 1572, 339.32, 3475.36, 8444.8, 12259.48),
#  (5913, 2971, '2013-12-30 04:40:17', 41, 0, 0, 41, 204.59, 0, 0, 204.59),
#  (5979, 3101, '2013-12-31 13:14:55', 485, 191, 0, 676, 2420.15, 1430.59, 0, 3850.74),
#  (6007, 3141, '2013-12-08 20:13:49', 0, 49, 1401, 1450, 0, 367.01, 11376.12, 11743.13),
#  (6078, 3251, '2013-12-06 13:14:47', 75, 405, 403, 883, 374.25, 3033.45, 3272.36, 6680.06),
#  (6157, 3411, '2013-12-13 18:20:51', 0, 493, 309, 802, 0, 3692.57, 2509.08, 6201.65),
#  (6197, 3431, '2013-12-06 12:55:22', 53, 559, 315, 927, 264.47, 4186.91, 2557.8, 7009.18),
#  (6277, 3491, '2013-12-06 23:45:16', 12, 85, 48, 145, 59.88, 636.65, 389.76, 1086.29),
#  (6575, 4111, '2013-12-25 21:03:52', 58, 534, 287, 879, 289.42, 3999.66, 2330.44, 6619.52),
#  (6603, 4151, '2013-12-22 11:24:55', 67, 515, 269, 851, 334.33, 3857.35, 2184.28, 6375.96),
#  (6677, 4211, '2013-12-12 09:54:34', 514, 604, 196, 1314, 2564.86, 4523.96, 1591.52, 8680.34),
#  (6755, 4291, '2013-12-28 18:26:50', 84, 503, 502, 1089, 419.16, 3767.47, 4076.24, 8262.87),
#  (6808, 4341, '2013-12-10 16:10:52', 0, 78, 37, 115, 0, 584.22, 300.44, 884.66),
#  (6896, 4491, '2013-12-08 06:34:23', 43, 520, 242, 805, 214.57, 3894.8, 1965.04, 6074.41)]

# %%
# %%sql
# SELECT *
# FROM
# ORDER BY
# LIMIT 5

# %%
# %%sql
# SELECT *
# FROM
# ORDER BY
# LIMIT 5

# %%
# %%sql
# SELECT *
# FROM
# ORDER BY
# LIMIT 5

# %%
Which channels 
SELECT *
FROM web_events
WHERE channel IN ('organic', 'adwords') AND occurred_at BETWEEN '2016-01-01' AND '2017-01-01'
ORDER BY occurred_at DESC;

# %% [markdown]
# <div style="border: 5px solid #6f00ff;
#     border-radius: 20px; text-align: center; font-size: 20px; font-family: 'Merriweather'; padding: 16px 0; background-color: #F5E8DA">
#   <b>What are the 10 latest orders?<b>
# </div>

# %% [markdown]
# <div style="border: 5px solid #6f00ff;
#     border-radius: 20px; text-align: center; font-size: 20px; font-family: 'Merriweather'; padding: 16px 0; background-color: #F5E8DA">
#   <b>What are the 10 latest orders?<b>
# </div>

# %% [markdown]
# <div style="border: 5px solid #6f00ff;
#     border-radius: 20px; text-align: center; font-size: 20px; font-family: 'Merriweather'; padding: 16px 0; background-color: #F5E8DA">
#   <b>What are the 10 latest orders?<b>
# </div>

# %% [markdown]
# <div style="border: 5px solid #6f00ff;
#     border-radius: 20px; text-align: center; font-size: 20px; font-family: 'Merriweather'; padding: 16px 0; background-color: #F5E8DA">
#   <b>What are the 10 latest orders?<b>
# </div>

# %% [markdown]
# <div style="border: 10px solid #6f00ff;
#     border-radius: 20px; text-align: center; padding: 20px 0; background-color: #F5E8DA">
#   This is a curved edge border box with the color #6f00ff.
# </div>

# %% [markdown]
# <footer style="background-color: #3D0069; color: white ; font-family: 'Merriweather'; font-weight: bold; text-align: center; padding: 20px 0; font-size: 16px;">
#     <p style="text-align: center;"> <i>Datavestigating to connect the facts</i> </p>
#     <p style="font-size: 14px; text-align: center;">&copy; The Datavestigator</p>
# </footer>
